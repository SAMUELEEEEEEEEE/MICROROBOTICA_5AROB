# %% [markdown]
# ### Esercizio

# %%
import numpy as np

# %%
dimensione_array_pm10 = 1000
dimensione_indici_caso = 20

# %%
array_pm10 = np.random.normal(19, 5, dimensione_array_pm10)

# %%
indici_caso = np.random.randint(0, len(array_pm10), dimensione_indici_caso)

# %%
array_pm10[indici_caso] = 999.99

# %%
array_pm10
# Out:
# array([ 18.05146064,  17.89249104,  26.77864753,  20.26238892,
#         24.71730032,  11.41359594,  12.89445026,  15.92969224,
#         25.13905798,  19.5168223 ,  19.23166066,  23.67701515,
#         22.10279549,  21.10194956,  10.39993952,  20.41291322,
#         21.73856157, 999.99      ,  24.73003675,  18.21009899,
#         23.48977874,  25.76127059,  14.44634348,  22.93703652,
#         27.6967727 ,  27.22298277,  16.9296228 ,  25.27807199,
#         16.27793668,  25.31924419,  21.41395814,  13.17997765,
#         17.04212628,  27.12838983,  14.03473998,  16.38521843,
#         18.03219169,  16.07557546,  17.20466117,  21.98421629,
#         17.09223942,  15.40106023,  10.07827882,  22.25403906,
#         22.22181986,  17.63138431,  29.78639805,  23.50000063,
#         13.67246618,  19.12596107,  21.2320151 ,  16.92117047,
#         20.46228534, 999.99      ,  13.49848901,  21.01297939,
#         27.67613872,  20.75797384,  12.71652403,  21.19632547,
# ...
