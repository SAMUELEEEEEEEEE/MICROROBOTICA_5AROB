# %%
import pandas as pd

# %% [markdown]
# ### Esercizio 1

# %%
data = pd.read_csv("02_laureatixateneo.csv", sep = ";")

# %%
data
# Out:
#       AnnoS  AteneoCOD          AteneoNOME SESSO   Lau
# 0      2022        101              Torino     F  8928
# 1      2022        101              Torino     M  5269
# 2      2022        102  Torino Politecnico     F  2442
# 3      2022        102  Torino Politecnico     M  5349
# 4      2022        201  Piemonte Orientale     F  1344
# ...     ...        ...                 ...   ...   ...
# 3726   2001       8701             Catania     M  1663
# 3727   2001       9001             Sassari     F   922
# 3728   2001       9001             Sassari     M   508
# 3729   2001       9201            Cagliari     F  2023
# 3730   2001       9201            Cagliari     M  1263
#
# [3731 rows x 5 columns]

# %%
data[["AteneoNOME", "Lau"]].groupby("AteneoNOME").sum()
# Out:
#                                               Lau
# AteneoNOME
# Aosta                                        3256
# Bari                                       165555
# Bari Politecnico                            35560
# Basilicata                                  18611
# Benevento Giustino Fortunato - telematica    3251
# ...                                           ...
# Tuscia                                      35075
# Udine                                       61605
# Urbino                                      62355
# Venezia Iuav                                31703
# Verona                                      87965
#
# [92 rows x 1 columns]

# %% [markdown]
# ### Esercizio 2

# %%
data = pd.read_csv("07_laureatixresidenza.csv", sep = ";")

# %%
data
# Out:
#         AnnoS  CODIstatProv            ProvinciaRES  CODIstatComune  \
# 0        2022             1                  TORINO            1001
# 1        2022             1                  TORINO            1001
# 2        2022             1                  TORINO            1002
# 3        2022             1                  TORINO            1002
# 4        2022             1                  TORINO            1003
# ...       ...           ...                     ...             ...
# 180381   2010           998        PROVINCIA ESTERA          702702
# 180382   2010           998        PROVINCIA ESTERA          999998
# 180383   2010           998        PROVINCIA ESTERA          999998
# 180384   2010           999  PROVINCIA NON DEFINITA          999999
# 180385   2010           999  PROVINCIA NON DEFINITA          999999
#
#                  ComuneRES SESSO   Lau
# 0                   AGLIE'     F     8
# 1                   AGLIE'     M     5
# ...

# %%
data[["ProvinciaRES", "ComuneRES", "Lau"]].groupby(["ProvinciaRES", "ComuneRES"]).sum()
# Out:
#                                             Lau
# ProvinciaRES ComuneRES
# AGRIGENTO    AGRIGENTO                     6017
#              ALESSANDRIA DELLA ROCCA        311
#              ARAGONA                        982
#              BIVONA                         354
#              BURGIO                         242
# ...                                         ...
# VITERBO      VETRALLA                       852
#              VIGNANELLO                     271
#              VILLA SAN GIOVANNI IN TUSCIA   106
#              VITERBO                       5996
#              VITORCHIANO                    371
#
# [8000 rows x 1 columns]

# %% [markdown]
# ### Esercizio 3

# %%
data = pd.read_csv("04_laureatixtipocorso.csv",  sep = ";")

# %%
data
# Out:
#      AnnoS                                       CorsoTIPO SESSO     Lau
# 0     2022     Laurea Magistrale a Ciclo Unico - dm 270/04     M   12989
# 1     2022                             Laurea  - dm 509/99     F     476
# 2     2022           Corso di Laurea - vecchio ordinamento     F     360
# 3     2022                              Laurea - dm 270/04     F  111540
# 4     2022  Laurea Specialistica a Ciclo Unico - dm 509/99     F     246
# ..     ...                                             ...   ...     ...
# 258   2001           Corso di Laurea - vecchio ordinamento     F   96619
# 259   2001                             Laurea  - dm 509/99     M     705
# 260   2001                Laurea Specialistica - dm 509/99     M       5
# 261   2001           Corso di Laurea - vecchio ordinamento     M   73913
# 262   2001                Laurea Specialistica - dm 509/99     F       2
#
# [263 rows x 4 columns]

# %%
data[["SESSO", "Lau"]].groupby("SESSO").sum()
# Out:
#            Lau
# SESSO
# F      3787707
# M      2778121

# %% [markdown]
# ### Esercizio 4

# %%
data = pd.read_csv("04_laureatixtipocorso.csv", sep = ";")

# %%
data
# Out:
#      AnnoS                                       CorsoTIPO SESSO     Lau
# 0     2022     Laurea Magistrale a Ciclo Unico - dm 270/04     M   12989
# 1     2022                             Laurea  - dm 509/99     F     476
# 2     2022           Corso di Laurea - vecchio ordinamento     F     360
# 3     2022                              Laurea - dm 270/04     F  111540
# 4     2022  Laurea Specialistica a Ciclo Unico - dm 509/99     F     246
# ..     ...                                             ...   ...     ...
# 258   2001           Corso di Laurea - vecchio ordinamento     F   96619
# 259   2001                             Laurea  - dm 509/99     M     705
# 260   2001                Laurea Specialistica - dm 509/99     M       5
# 261   2001           Corso di Laurea - vecchio ordinamento     M   73913
# 262   2001                Laurea Specialistica - dm 509/99     F       2
#
# [263 rows x 4 columns]

# %%
data[["CorsoTIPO", "Lau"]].groupby("CorsoTIPO").sum()
# Out:
#                                                     Lau
# CorsoTIPO
# Corso di Laurea - vecchio ordinamento           1146963
# Laurea  - dm 509/99                             1541784
# Laurea - dm 270/04                              1828833
# Laurea Magistrale - dm 270/04                   1105416
# Laurea Magistrale a Ciclo Unico - dm 270/04      380732
# Laurea Specialistica - dm 509/99                 413810
# Laurea Specialistica a Ciclo Unico - dm 509/99   148290

# %% [markdown]
# ### Esercizio 5

# %%
data = pd.read_csv("04_laureatixtipocorso.csv", sep = ";")

# %%
data
# Out:
#      AnnoS                                       CorsoTIPO SESSO     Lau
# 0     2022     Laurea Magistrale a Ciclo Unico - dm 270/04     M   12989
# 1     2022                             Laurea  - dm 509/99     F     476
# 2     2022           Corso di Laurea - vecchio ordinamento     F     360
# 3     2022                              Laurea - dm 270/04     F  111540
# 4     2022  Laurea Specialistica a Ciclo Unico - dm 509/99     F     246
# ..     ...                                             ...   ...     ...
# 258   2001           Corso di Laurea - vecchio ordinamento     F   96619
# 259   2001                             Laurea  - dm 509/99     M     705
# 260   2001                Laurea Specialistica - dm 509/99     M       5
# 261   2001           Corso di Laurea - vecchio ordinamento     M   73913
# 262   2001                Laurea Specialistica - dm 509/99     F       2
#
# [263 rows x 4 columns]

# %%
data[["CorsoTIPO", "SESSO", "Lau"]].groupby(["CorsoTIPO", "SESSO"]).sum()
# Out:
#                                                           Lau
# CorsoTIPO                                      SESSO
# Corso di Laurea - vecchio ordinamento          F       678779
#                                                M       468184
# Laurea  - dm 509/99                            F       879242
#                                                M       662542
# Laurea - dm 270/04                             F      1049464
#                                                M       779369
# Laurea Magistrale - dm 270/04                  F       624102
#                                                M       481314
# Laurea Magistrale a Ciclo Unico - dm 270/04    F       237349
#                                                M       143383
# Laurea Specialistica - dm 509/99               F       224904
#                                                M       188906
# Laurea Specialistica a Ciclo Unico - dm 509/99 F        93867
# ...
