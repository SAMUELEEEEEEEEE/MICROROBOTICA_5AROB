# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("Temperature_Anomaly.csv")
data
# Out:
#      Year  Value
# 0    1880  -0.18
# 1    1881  -0.10
# 2    1882  -0.14
# 3    1883  -0.01
# 4    1884  -0.20
# ..    ...    ...
# 133  2013   0.68
# 134  2014   0.76
# 135  2015   0.89
# 136  2016   0.91
# 137  2017   0.79
#
# [138 rows x 2 columns]

# %%
years = data["Year"].values
values = data["Value"].values

# %%
fig, axs = plt.subplots(nrows = 2, figsize = (8, 8))
axs[0].plot(years, values)
axs[0].set_xlabel("years")
axs[0].set_ylabel("values")
axs[0].set_title("Anomalie della temperatura")
axs[0].grid()

axs[1].hist(values, bins = 69)
axs[1].set_xlabel("values")
axs[1].set_ylabel("frequency")

plt.show()
