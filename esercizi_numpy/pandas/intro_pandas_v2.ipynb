# %%
import pandas as pd

# %%
dictionary = {"Matematica" : [6, 7, 8], "Inglese" : [4.5, 8, 6]}

# %%
data = pd.DataFrame(dictionary) #Crea un dataframe a partire da un dizionario

# %%
data
# Out:
#    Matematica  Inglese
# 0           6      4.5
# 1           7      8.0
# 2           8      6.0

# %%
data.to_html("prova.html")

# %%
data = pd.read_csv("Fuel_Consumption_2000-2022.csv")

# %%
data
# Out:
#        YEAR   MAKE        MODEL  VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0      2000  ACURA        1.6EL        COMPACT          1.6          4
# 1      2000  ACURA        1.6EL        COMPACT          1.6          4
# 2      2000  ACURA        3.2TL       MID-SIZE          3.2          6
# 3      2000  ACURA        3.5RL       MID-SIZE          3.5          6
# 4      2000  ACURA      INTEGRA     SUBCOMPACT          1.8          4
# ...     ...    ...          ...            ...          ...        ...
# 22551  2022  VOLVO  XC40 T5 AWD     SUV: SMALL          2.0          4
# 22552  2022  VOLVO  XC60 B5 AWD     SUV: SMALL          2.0          4
# 22553  2022  VOLVO  XC60 B6 AWD     SUV: SMALL          2.0          4
# 22554  2022  VOLVO  XC90 T5 AWD  SUV: STANDARD          2.0          4
# 22555  2022  VOLVO  XC90 T6 AWD  SUV: STANDARD          2.0          4
#
#       TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 KM)  COMB (L/100 KM)  \
# ...

# %% [markdown]
# ## Selezionare colonne

# %%
data["MAKE"]  #colonna marca -> data[nomeColonna]
# Out:
# 0        ACURA
# 1        ACURA
# 2        ACURA
# 3        ACURA
# 4        ACURA
#          ...
# 22551    VOLVO
# 22552    VOLVO
# 22553    VOLVO
# 22554    VOLVO
# 22555    VOLVO
# Name: MAKE, Length: 22556, dtype: object

# %%
data["MAKE"].values #colonna marca in array numpy
# Out:
# array(['ACURA', 'ACURA', 'ACURA', ..., 'VOLVO', 'VOLVO', 'VOLVO'],
#       dtype=object)

# %%
data[["MAKE", "FUEL", "EMISSIONS"]] #più colonne
# Out:
#         MAKE FUEL  EMISSIONS
# 0      ACURA    X        186
# 1      ACURA    X        175
# 2      ACURA    Z        230
# 3      ACURA    Z        264
# 4      ACURA    X        198
# ...      ...  ...        ...
# 22551  VOLVO    Z        219
# 22552  VOLVO    Z        219
# 22553  VOLVO    Z        232
# 22554  VOLVO    Z        236
# 22555  VOLVO    Z        252
#
# [22556 rows x 3 columns]

# %%
array = data[["MAKE", "FUEL", "EMISSIONS"]].values #matrice delle colonne

# %%
array.shape
# Out:
# (22556, 3)

# %% [markdown]
# ## Selezionare righe

# %%
data[data["MAKE"] == "VOLVO"]
# Out:
#        YEAR   MAKE                  MODEL  VEHICLE CLASS  ENGINE SIZE  \
# 618    2000  VOLVO  C70 CONVERTIBLE TURBO     SUBCOMPACT          2.3
# 619    2000  VOLVO  C70 CONVERTIBLE TURBO     SUBCOMPACT          2.3
# 620    2000  VOLVO  C70 CONVERTIBLE TURBO     SUBCOMPACT          2.4
# 621    2000  VOLVO              C70 TURBO        COMPACT          2.3
# 622    2000  VOLVO              C70 TURBO        COMPACT          2.3
# ...     ...    ...                    ...            ...          ...
# 22551  2022  VOLVO            XC40 T5 AWD     SUV: SMALL          2.0
# 22552  2022  VOLVO            XC60 B5 AWD     SUV: SMALL          2.0
# 22553  2022  VOLVO            XC60 B6 AWD     SUV: SMALL          2.0
# 22554  2022  VOLVO            XC90 T5 AWD  SUV: STANDARD          2.0
# 22555  2022  VOLVO            XC90 T6 AWD  SUV: STANDARD          2.0
#
#        CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 KM)  \
# ...

# %%
volvo_200 = data[(data["MAKE"] == "VOLVO") & (data["EMISSIONS"] <= 200)].copy()
volvo_200
# Out:
#        YEAR   MAKE               MODEL          VEHICLE CLASS  ENGINE SIZE  \
# 9970   2010  VOLVO              C30 T5                COMPACT          2.5
# 9971   2010  VOLVO              C30 T5                COMPACT          2.5
# 9976   2010  VOLVO              S40 T5                COMPACT          2.5
# 9977   2010  VOLVO              S40 T5                COMPACT          2.5
# 9985   2010  VOLVO              V50 T5  STATION WAGON - SMALL          2.5
# 9986   2010  VOLVO              V50 T5  STATION WAGON - SMALL          2.5
# 11057  2011  VOLVO              C30 T5                COMPACT          2.5
# 11058  2011  VOLVO              C30 T5                COMPACT          2.5
# 11061  2011  VOLVO              S40 T5                COMPACT          2.5
# 11065  2011  VOLVO              V50 T5  STATION WAGON - SMALL          2.5
# 12140  2012  VOLVO              C30 T5                COMPACT          2.5
# ...

# %%
volvo_200[["FUEL", "FUEL CONSUMPTION", "EMISSIONS"]]
# Out:
#       FUEL  FUEL CONSUMPTION  EMISSIONS
# 9970     X              10.2        200
# 9971     X              10.2        200
# 9976     X              10.2        200
# 9977     X              10.2        200
# 9985     X              10.2        200
# 9986     X              10.2        200
# 11057    X              10.1        198
# 11058    X              10.2        200
# 11061    X              10.1        198
# 11065    X              10.1        198
# 12140    X              10.1        198
# 12141    X              10.2        200
# 13199    X              10.1        198
# 13200    X              10.2        200
# 13202    X               9.9        193
# 14242    X               9.9        193
# 15365    X               9.8        193
# 15369    X               9.8        193
# 15374    X               9.8        193
# 16470    X               9.6        193
# 16472    X               9.6        193
# 16478    X               9.6        193
# ...

# %% [markdown]
# ## Funzione di aggregazione

# %%
data["EMISSIONS"].max()
# Out:
# 608

# %%
data["EMISSIONS"].count()
# Out:
# 22556

# %%
data["EMISSIONS"].mean()
# Out:
# 250.06845185316544

# %%
data["EMISSIONS"].std()
# Out:
# 59.355276326282905

# %%
data[data["MAKE"] == "VOLVO"]["EMISSIONS"].max()
# Out:
# 315

# %%
data["MAKE"].unique() #Valori univoci -- distinct
# Out:
# array(['ACURA', 'AUDI', 'BMW', 'BUICK', 'CADILLAC', 'CHEVROLET',
#        'CHRYSLER', 'DAEWOO', 'DODGE', 'FERRARI', 'FORD', 'GMC', 'HONDA',
#        'HYUNDAI', 'INFINITI', 'ISUZU', 'JAGUAR', 'JEEP', 'KIA',
#        'LAND ROVER', 'LEXUS', 'LINCOLN', 'MAZDA', 'MERCEDES-BENZ',
#        'NISSAN', 'OLDSMOBILE', 'PLYMOUTH', 'PONTIAC', 'PORSCHE', 'SAAB',
#        'SATURN', 'SUBARU', 'SUZUKI', 'TOYOTA', 'VOLKSWAGEN', 'VOLVO',
#        'BENTLEY', 'ROLLS-ROYCE', 'MASERATI', 'MINI', 'MITSUBISHI',
#        'SMART', 'HUMMER', 'ASTON MARTIN', 'LAMBORGHINI', 'BUGATTI',
#        'SCION', 'FIAT', 'RAM', 'SRT', 'ALFA ROMEO', 'GENESIS'],
#       dtype=object)

# %%
data["FUEL"].unique()
# Out:
# array(['X', 'Z', 'E', 'N', 'D'], dtype=object)

# %%
data[data["MAKE"] == "AUDI"]["TRANSMISSION"].unique()
# Out:
# array(['A5', 'M5', 'M6', 'AV', 'AS5', 'AS6', 'AS7', 'AS8', 'AM6', 'AV8',
#        'AM7', 'A7', 'A6', 'AM8'], dtype=object)

# %%
data[["MAKE", "FUEL CONSUMPTION"]].groupby("MAKE").mean()   #group by, una colonna che raggruppo e una che aggrego
# Out:
#                FUEL CONSUMPTION
# MAKE
# ACURA                 10.937652
# ALFA ROMEO            11.104762
# ASTON MARTIN          17.026415
# AUDI                  12.496894
# BENTLEY               19.685593
# BMW                   12.730537
# BUGATTI               27.650000
# BUICK                 12.182051
# CADILLAC              13.696313
# CHEVROLET             14.352019
# CHRYSLER              12.698824
# DAEWOO                10.535294
# DODGE                 15.147459
# FERRARI               21.683562
# FIAT                   8.842353
# FORD                  13.569026
# GENESIS               13.495238
# GMC                   16.188357
# HONDA                  9.381640
# HUMMER                16.390476
# HYUNDAI               10.052941
# INFINITI              12.596071
# ISUZU                 14.888889
# JAGUAR                13.376374
# JEEP                  12.529963
# KIA                   10.142669
# LAMBORGHINI           21.001802
# LAND ROVER            15.174713
# ...

# %%
data[["MAKE", "FUEL CONSUMPTION", "EMISSIONS"]].groupby("MAKE").mean()
# Out:
#                FUEL CONSUMPTION   EMISSIONS
# MAKE
# ACURA                 10.937652  219.599190
# ALFA ROMEO            11.104762  228.119048
# ASTON MARTIN          17.026415  332.188679
# AUDI                  12.496894  247.595031
# BENTLEY               19.685593  375.652542
# BMW                   12.730537  250.785235
# BUGATTI               27.650000  538.250000
# BUICK                 12.182051  232.047619
# CADILLAC              13.696313  264.313364
# CHEVROLET             14.352019  269.999531
# CHRYSLER              12.698824  236.108235
# DAEWOO                10.535294  204.000000
# DODGE                 15.147459  283.115676
# FERRARI               21.683562  411.000000
# FIAT                   8.842353  184.364706
# FORD                  13.569026  260.672274
# GENESIS               13.495238  275.928571
# GMC                   16.188357  301.874724
# HONDA                  9.381640  191.475936
# HUMMER                16.390476  317.952381
# ...

# %%
query = data[["MAKE", "FUEL", "FUEL CONSUMPTION", "EMISSIONS"]].groupby(["MAKE", "FUEL"]).mean()  #Due dati nel group by
query
# Out:
#                    FUEL CONSUMPTION   EMISSIONS
# MAKE         FUEL
# ACURA        X             8.815789  177.789474
#              Z            11.323445  227.200957
# ALFA ROMEO   Z            11.104762  228.119048
# ASTON MARTIN Z            17.026415  332.188679
# AUDI         D             9.836364  226.090909
# ...                             ...         ...
# VOLKSWAGEN   E            17.300000  232.000000
#              X            10.129321  204.216049
#              Z            11.111254  219.668810
# VOLVO        X            11.549133  228.150289
#              Z            11.681871  231.152047
#
# [120 rows x 2 columns]

# %%
data[["MAKE", "FUEL"]].value_counts() #Aggregazione utile per i conteggi
# Out:
# MAKE           FUEL
# CHEVROLET      X       1495
# BMW            Z       1461
# FORD           X       1444
# MERCEDES-BENZ  Z       1221
# PORSCHE        Z        986
#                        ...
# PLYMOUTH       Z          2
# OLDSMOBILE     Z          1
# VOLKSWAGEN     E          1
# MAZDA          D          1
# SATURN         E          1
# Length: 120, dtype: int64

# %%
data["ENGINE SIZE CM3"] = data["ENGINE SIZE"] * 1000
data
# Out:
#        YEAR   MAKE        MODEL  VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0      2000  ACURA        1.6EL        COMPACT          1.6          4
# 1      2000  ACURA        1.6EL        COMPACT          1.6          4
# 2      2000  ACURA        3.2TL       MID-SIZE          3.2          6
# 3      2000  ACURA        3.5RL       MID-SIZE          3.5          6
# 4      2000  ACURA      INTEGRA     SUBCOMPACT          1.8          4
# ...     ...    ...          ...            ...          ...        ...
# 22551  2022  VOLVO  XC40 T5 AWD     SUV: SMALL          2.0          4
# 22552  2022  VOLVO  XC60 B5 AWD     SUV: SMALL          2.0          4
# 22553  2022  VOLVO  XC60 B6 AWD     SUV: SMALL          2.0          4
# 22554  2022  VOLVO  XC90 T5 AWD  SUV: STANDARD          2.0          4
# 22555  2022  VOLVO  XC90 T6 AWD  SUV: STANDARD          2.0          4
#
#       TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 KM)  COMB (L/100 KM)  \
# ...
